# %% [markdown]
# # Test the format of output data

# %%
# read data humans and LLM processed data
# packages
import pandas as pd
import numpy as np
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt
from utils import load_dataframes, filter_pred_prob
# load overall df
LLM_data = pd.read_csv("processed_data/final_DVs.csv")
human_data = pd.read_csv("orig_human_data/quest_scores.csv")

# %%
human_data.columns
# Out:
# Index(['partid', 'ses', 'ses_moth', 'ses_fath', 'famstat', 'sibl', 'sibl_y',
#        'sibl_o', 'birthrank', 'edu', 'household', 'birthplace', 'income',
#        'location', 'AUDIT', 'FTND', 'GABS', 'PG', 'DAST', 'NUM', 'SOEP',
#        'SOEPdri', 'SOEPfin', 'SOEPrec', 'SOEPocc', 'SOEPhea', 'SOEPsoc',
#        'CAREaggr', 'CAREsex', 'CAREwork', 'Deth', 'Dinv', 'Dgam', 'Dhea',
#        'Drec', 'Dsoc', 'Deth_r', 'Dinv_r', 'Dgam_r', 'Dhea_r', 'Drec_r',
#        'Dsoc_r', 'Deth_b', 'Dinv_b', 'Dgam_b', 'Dhea_b', 'Drec_b', 'Dsoc_b',
#        'Dy', 'Dm', 'PRI', 'PRIw', 'BIS1att', 'BIS1mot', 'BIS1ctr', 'BIS1com',
#        'BIS1per', 'BIS1ins', 'BIS2att', 'BIS2mot', 'BIS2npl', 'BIS', 'SStas',
#        'SSexp', 'SSdis', 'SSbor', 'SSSV', 'BMI'],
#       dtype='object')

# %%
human_data['SSbor'].describe()
# Out:
# count    1507.000000
# mean       14.244857
# std         1.954096
# min        10.000000
# 25%        13.000000
# 50%        14.000000
# 75%        16.000000
# max        20.000000
# Name: SSbor, dtype: float64

# %%
LLM_data['MPL'].describe()
# Out:
# count    46.000000
# mean      3.717391
# std       0.544183
# min       3.000000
# 25%       3.000000
# 50%       4.000000
# 75%       4.000000
# max       5.000000
# Name: MPL, dtype: float64

# %%
LLM_data.columns
# Out:
# Index(['model', 'AUDIT', 'BISa', 'BISm', 'BISn', 'CAREa', 'CAREs', 'CAREw',
#        'DAST', 'DM', 'Deth', 'Dgam', 'Dhea', 'Dinv', 'Drec', 'Dsoc', 'FTND',
#        'GABS', 'PG', 'PRI_certainty', 'PRI_decision', 'SOEP', 'SOEPdri',
#        'SOEPfin', 'SOEPhea', 'SOEPocc', 'SOEPrec', 'SOEPsoc', 'SSbor', 'SSdis',
#        'SSexp', 'SStas', 'BART', 'CCT', 'DFD', 'DFE', 'LOT', 'MPL'],
#       dtype='object')
