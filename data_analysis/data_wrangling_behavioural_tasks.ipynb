# %% [markdown]
# # Data Wrangling with Behavioural Tasks
# Starting point:
# - 848 datasets (18 tasks per model (minus the NON_IDEAL_OUTPUTS)) with all logprobs for all answer alternatives of each subtask for all ~1.500 tasks.
#
# What does this script do
# - Read data sets: Which?
# - ...
#
# Goal:
# - first have one value per item per model
# - then transform those values in "outcomes" for each subscale (like Frey did)
# - Have 36 values per model! (one per (sub-) scale).

# %% [markdown]
# ## Packages & Helpers

# %%
# packages
import pandas as pd
import numpy as np
import glob
import os
import matplotlib.pyplot as plt
from utils import load_dataframes

# load overall df
all_data = pd.read_csv("processed_data/items_per_LLM.csv")

# %%
# Helpers

# filter out probability LLM assigned to real item answer  ------------------------------------------
def filter_pred_prob(data, key1_column="box_1_key", key2_column= "box_2_key"):
    # Determine whether the human decision matches box_1 or box_2
    mask_box1 = data["human_decision"] == data[key1_column]
    mask_box2 = data["human_decision"] == data[key2_column]

    # Assign probability based on which box matches
    data["prob_pred"] = data["prob_1"].where(mask_box1, data["prob_2"].where(mask_box2, None))
    
    return data

# %% [markdown]
# ## BART TASK

# %% [markdown]
# Question:
# - Wie soll ich hier über verschiedene Menschen zusammenfassen, wenn die Situation und Entscheidung für jeden Menschen individuell ist?
# - same bei DFE (unterschiedliche Experience bei Karten samplen durch randomness) und CCT (auch wieder randomness involviert)
# - bei DFE muss man die sampling decision, die ja wesentlich die chosse decision beeinflussen sollte, ohnehin noch aus den menschlichen Daten aussuchen und irgendwie hinzufügen

# %%
# load data
BART_data = load_dataframes(task_name="BART", path = "LLM_data")
# Out:
# Merged DataFrame shape: (74346712, 13)
# Total models: 44

# %%
#BART_data.head(60)

# %% [markdown]
# ## CCT TASK

# %%
# load data
CCT_data = load_dataframes(task_name="CCT")
# Out:
# Merged DataFrame shape: (23305362, 16)
# Total models: 38

# %%
#CCT_data.head(30)

# %% [markdown]
# ## DFD TASK

# %%
# load data
DFD_data = load_dataframes(task_name="DFD")
DFD_human_data = pd.read_csv("orig_human_data/dfd_perprob.csv")
# Out:
# Merged DataFrame shape: (554576, 9)
# Total models: 46

# %%
# normalise answer option sum to one
DFD_data["prob_1"] = np.exp(DFD_data["log_prob_box_1"])/(np.exp(DFD_data["log_prob_box_1"]) + np.exp(DFD_data["log_prob_box_2"]))
DFD_data["prob_2"] = np.exp(DFD_data["log_prob_box_2"])/(np.exp(DFD_data["log_prob_box_1"]) + np.exp(DFD_data["log_prob_box_2"]))

# %%
# filter out probability LLM assigned to real item answer 
DFD_data=filter_pred_prob(DFD_data)

# %%
# Merge only selected columns from DFD_human_data
DFD_data = DFD_data.merge(
    DFD_human_data[["partid", "gamble_ind", "gamble_lab", "H", "R"]],
    left_on=["participant", "round"],
    right_on=["partid", "gamble_ind"],
    how="left"
)

# Drop duplicate key columns if you don’t need them anymore
DFD_data = DFD_data.drop(columns=["partid", "gamble_ind"])

# %%
# produce df with one value per model per item -------------------------------------------------------
def get_LLM_value_per_item(data):
    grouped = data.groupby(["experiment", "model", "gamble_lab"])
    prob_sum = grouped["prob_pred"].sum()
    
    # compute weighted means
    scoreH = (grouped["H"].apply(lambda x: (x * data.loc[x.index, "prob_pred"]).sum()) / prob_sum)
    scoreR = (grouped["R"].apply(lambda x: (x * data.loc[x.index, "prob_pred"]).sum()) / prob_sum)
    
    # combine into one DataFrame
    result = pd.concat([scoreH, scoreR], axis=1).reset_index()
    result.columns = ["experiment", "model", "gamble_lab", "H_score", "R_score"]
    
    return result


model_item_scores_DFD = get_LLM_value_per_item(DFD_data)

# %%
# add_new_df
all_data = pd.concat([all_data, model_item_scores_DFD], ignore_index=True)

# %% [markdown]
# ## DFE TASK

# %%
# load data
DFE_data = load_dataframes(task_name="DFE")
# Out:
# Merged DataFrame shape: (458052, 9)
# Total models: 38

# %%
#DFE_data.head(30)

# %% [markdown]
# ## LOT TASK

# %%
# load data
LOT_data = load_dataframes(task_name="LOT")
LOT_human_data = pd.read_csv("orig_human_data/lotteries.csv")
# Out:
# Merged DataFrame shape: (1733050, 9)
# Total models: 46

# %%
LOT_data.head(30)
# Out:
#    human_decision  log_prob_box_1  log_prob_box_2                  model  \
# 0               P         -19.125         -15.875  Falcon-3-10B-Instruct
# 1               V         -24.375         -20.625  Falcon-3-10B-Instruct
# 2               V         -25.125         -23.000  Falcon-3-10B-Instruct
# 3               P         -30.250         -30.375  Falcon-3-10B-Instruct
# 4               P         -28.750         -27.000  Falcon-3-10B-Instruct
# 5               V         -29.250         -27.750  Falcon-3-10B-Instruct
# 6               P         -32.750         -31.250  Falcon-3-10B-Instruct
# 7               P         -30.250         -30.750  Falcon-3-10B-Instruct
# 8               V         -34.250         -31.875  Falcon-3-10B-Instruct
# 9               V         -22.625         -22.125  Falcon-3-10B-Instruct
# 10              P         -29.625         -29.250  Falcon-3-10B-Instruct
# 11              V         -29.000         -27.625  Falcon-3-10B-Instruct
# 12              P         -30.625         -31.250  Falcon-3-10B-Instruct
# 13              V         -27.250         -27.000  Falcon-3-10B-Instruct
# 14              V         -24.375         -21.875  Falcon-3-10B-Instruct
# 15              V         -30.875         -28.500  Falcon-3-10B-Instruct
# 16              P         -22.750         -26.625  Falcon-3-10B-Instruct
# 17              P         -27.875         -30.375  Falcon-3-10B-Instruct
# 18              V         -25.750         -24.375  Falcon-3-10B-Instruct
# 19              P         -25.500         -25.000  Falcon-3-10B-Instruct
# 20              P         -29.250         -28.375  Falcon-3-10B-Instruct
# 21              V         -27.125         -26.375  Falcon-3-10B-Instruct
# 22              V         -32.000         -31.000  Falcon-3-10B-Instruct
# 23              V         -28.750         -29.250  Falcon-3-10B-Instruct
# 24              V         -28.375         -26.875  Falcon-3-10B-Instruct
# 25              R         -22.250         -18.125  Falcon-3-10B-Instruct
# 26              X         -22.500         -19.000  Falcon-3-10B-Instruct
# 27              R         -30.625         -27.000  Falcon-3-10B-Instruct
# 28              R         -29.625         -25.875  Falcon-3-10B-Instruct
# 29              R         -28.000         -24.375  Falcon-3-10B-Instruct
#
#     round  participant experiment box_1_key box_2_key
# 0       1     64000401   LOT task         V         P
# 1       2     64000401   LOT task         V         P
# 2       3     64000401   LOT task         V         P
# 3       4     64000401   LOT task         V         P
# 4       5     64000401   LOT task         V         P
# 5       6     64000401   LOT task         V         P
# 6       7     64000401   LOT task         V         P
# 7       8     64000401   LOT task         V         P
# 8       9     64000401   LOT task         V         P
# 9      10     64000401   LOT task         V         P
# 10     11     64000401   LOT task         V         P
# 11     12     64000401   LOT task         V         P
# 12     13     64000401   LOT task         V         P
# 13     14     64000401   LOT task         V         P
# 14     15     64000401   LOT task         V         P
# 15     16     64000401   LOT task         V         P
# 16     17     64000401   LOT task         V         P
# 17     18     64000401   LOT task         V         P
# 18     19     64000401   LOT task         V         P
# 19     20     64000401   LOT task         V         P
# 20     21     64000401   LOT task         V         P
# 21     22     64000401   LOT task         V         P
# 22     23     64000401   LOT task         V         P
# 23     24     64000401   LOT task         V         P
# 24     25     64000401   LOT task         V         P
# 25      1     64004701   LOT task         X         R
# 26      2     64004701   LOT task         X         R
# 27      3     64004701   LOT task         X         R
# 28      4     64004701   LOT task         X         R
# 29      5     64004701   LOT task         X         R

# %%
# normalise answer option sum to one
LOT_data["prob_1"] = np.exp(LOT_data["log_prob_box_1"])/(np.exp(LOT_data["log_prob_box_1"]) + np.exp(LOT_data["log_prob_box_2"]))
LOT_data["prob_2"] = np.exp(LOT_data["log_prob_box_2"])/(np.exp(LOT_data["log_prob_box_1"]) + np.exp(LOT_data["log_prob_box_2"]))

# %%
# filter out probability LLM assigned to real item answer 
LOT_data=filter_pred_prob(LOT_data)

# %%
LOT_human_data
# Out:
#          partid  Dec_ID  Stage  Substage  External_Dec_ID  V_Decision   X1  \
# 0      64000401       1      2         2              122           1   50
# 1      64000401       1      3         0              130           1   70
# 2      64000401       2      3         3              233           1  110
# 3      64000401       2      4         0              240           1   90
# 4      64000401       3      2         2              322           1   50
# ...         ...     ...    ...       ...              ...         ...  ...
# 75345  68051401      23      4         0             2340           0  -50
# 75346  68051401      24      2         2             2422           0  -50
# 75347  68051401      24      3         0             2430           0  -50
# 75348  68051401      25      2         2             2522           0  -10
# 75349  68051401      25      3         0             2530           0  -10
#
#         X2  PX1   Z1  ...  Maxstage  Presentation_Order  Presentation_XZ  \
# 0       20   70   90  ...         3                  44                0
# 1       20   70   90  ...         3                  82                1
# 2       70   70  160  ...         4                  26                0
# 3       70   70  160  ...         4                  47                0
# 4       10   75   80  ...         3                  48                0
# ...    ...  ...  ...  ...       ...                 ...              ...
# 75345 -120   30  -40  ...         4                  74                0
# 75346 -120   55  -40  ...         3                  38                1
# 75347 -120   30  -40  ...         3                  49                0
# 75348 -100   80  -20  ...         3                  29                1
# 75349 -100   40  -20  ...         3                  50                0
#
#        Decision_Time  Decision_X  Inconsistent  Change_X  Threshold_Up  \
# 0               5150           0           0.0         1            90
# 1               5581           0           NaN         1            90
# 2               9912           1           0.0         1           160
# 3               4453           1           NaN         1           110
# 4              13371           1           0.0         1            80
# ...              ...         ...           ...       ...           ...
# 75345          62147           0           NaN         0           -80
# 75346          17423           1           0.0         0           -50
# 75347          19239           0           NaN         0           -80
# 75348          15140           1           0.0         0           -10
# 75349          16119           0           NaN         0           -30
#
#        Threshold_Lo  R
# 0                20  1
# 1                50  1
# 2                70  0
# 3                70  0
# 4                20  0
# ...             ... ..
# 75345          -120  0
# 75346          -120  1
# 75347          -120  0
# 75348          -100  1
# 75349          -100  0
#
# [75350 rows x 22 columns]

# %%
# Merge only selected columns from DFD_human_data
LOT_data = LOT_data.merge(
    LOT_human_data[["partid", "Dec_ID", "R"]],
    left_on=["participant", "round"],
    right_on=["partid", "Dec_ID"],
    how="left"
)

# Drop duplicate key columns if you don’t need them anymore
LOT_data = LOT_data.drop(columns=["partid",  "Dec_ID"])

# %%
# produce df with one value per model per item -------------------------------------------------------
def get_LLM_value_per_item(data):
    grouped = data.groupby(["experiment", "model", "round"])
    prob_sum = grouped["prob_pred"].sum()
    
    # compute weighted mean
    R_score = (grouped["R"].apply(lambda x: (x * data.loc[x.index, "prob_pred"]).sum()) / prob_sum)
    return R_score.reset_index(name="R_score")



model_item_scores_LOT = get_LLM_value_per_item(LOT_data)

# %%
# add_new_df
all_data = pd.concat([all_data, model_item_scores_LOT], ignore_index=True)

# %% [markdown]
# LOT unvollständig!!!

# %% [markdown]
# ## MPL TASK

# %%
# load data
MPL_data = load_dataframes(task_name="MPL")
MPL_human_data = pd.read_csv("orig_human_data/mpl.csv")
# Out:
# Merged DataFrame shape: (4569180, 10)
# Total models: 46

# %%
# normalise answer option sum to one
MPL_data["prob_1"] = np.exp(MPL_data["log_prob_lot_1"])/(np.exp(MPL_data["log_prob_lot_1"]) + np.exp(MPL_data["log_prob_lot_2"]))
MPL_data["prob_2"] = np.exp(MPL_data["log_prob_lot_2"])/(np.exp(MPL_data["log_prob_lot_1"]) + np.exp(MPL_data["log_prob_lot_2"]))

# %%
# filter out probability LLM assigned to real item answer 
MPL_data=filter_pred_prob(MPL_data, "lot_1_key", "lot_2_key")

# %%
# Merge only selected columns from DFD_human_data
MPL_data = MPL_data.merge(
    MPL_human_data[["partid", "dp", "decision", "choice", "R"]],
    left_on=["participant", "problem", "decision"],
    right_on=["partid", "dp", "decision"],
    how="left"
)

# Drop duplicate key columns if you don’t need them anymore
MPL_data = MPL_data.drop(columns=["partid",  "dp"])

# %%
# produce df with one value per model per item -------------------------------------------------------
def get_LLM_value_per_item(data):
    grouped = data.groupby(["experiment", "model", "problem", "decision"])
    prob_sum = grouped["prob_pred"].sum()
    
    # compute weighted means
    scoreChoice = (grouped["choice"].apply(lambda x: (x * data.loc[x.index, "prob_pred"]).sum()) / prob_sum)
    scoreR = (grouped["R"].apply(lambda x: (x * data.loc[x.index, "prob_pred"]).sum()) / prob_sum)
    
    # combine into one DataFrame
    result = pd.concat([scoreChoice, scoreR], axis=1).reset_index()
    result.columns = ["experiment", "model", "problem", "decision", "scoreChoice", "R_score"]
    
    return result


model_item_scores_MPL = get_LLM_value_per_item(MPL_data)

# %%
# add_new_df
all_data = pd.concat([all_data, model_item_scores_MPL], ignore_index=True)

# %% [markdown]
# # Save final complete data

# %%
# save data
all_data.to_csv('processed_data/items_per_LLM.csv', index=False)

# %%
all_data
# Out:
#         experiment                      model  item     score category  \
# 0      AUDIT scale  Apertus-70B-Instruct-2509   1.0  1.072054      NaN
# 1      AUDIT scale  Apertus-70B-Instruct-2509   2.0  3.674954      NaN
# 2      AUDIT scale  Apertus-70B-Instruct-2509   3.0  1.656189      NaN
# 3      AUDIT scale  Apertus-70B-Instruct-2509   4.0  2.163460      NaN
# 4      AUDIT scale  Apertus-70B-Instruct-2509   5.0  1.134567      NaN
# ...            ...                        ...   ...       ...      ...
# 16371     MPL task             zephyr-7b-beta   NaN       NaN      NaN
# 16372     MPL task             zephyr-7b-beta   NaN       NaN      NaN
# 16373     MPL task             zephyr-7b-beta   NaN       NaN      NaN
# 16374     MPL task             zephyr-7b-beta   NaN       NaN      NaN
# 16375     MPL task             zephyr-7b-beta   NaN       NaN      NaN
#
#       reverse_coded gamble_lab  H_score   R_score  round  problem  decision  \
# 0               NaN        NaN      NaN       NaN    NaN      NaN       NaN
# 1               NaN        NaN      NaN       NaN    NaN      NaN       NaN
# 2               NaN        NaN      NaN       NaN    NaN      NaN       NaN
# 3               NaN        NaN      NaN       NaN    NaN      NaN       NaN
# 4               NaN        NaN      NaN       NaN    NaN      NaN       NaN
# ...             ...        ...      ...       ...    ...      ...       ...
# 16371           NaN        NaN      NaN  0.081935    NaN      7.0       2.0
# 16372           NaN        NaN      NaN  0.319287    NaN      7.0       3.0
# 16373           NaN        NaN      NaN  0.728582    NaN      7.0       4.0
# 16374           NaN        NaN      NaN  0.924115    NaN      7.0       5.0
# 16375           NaN        NaN      NaN  0.968179    NaN      7.0       6.0
#
#        scoreChoice
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# ...            ...
# 16371     0.081935
# 16372     0.319287
# 16373     0.728582
# 16374     0.924115
# 16375     0.968179
#
# [16376 rows x 13 columns]
